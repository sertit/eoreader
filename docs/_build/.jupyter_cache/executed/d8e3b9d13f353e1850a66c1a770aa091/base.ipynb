# %%
# Imports
import os
from eoreader.reader import Reader
from eoreader.bands import GREEN
from eoreader.keywords import CLEAN_OPTICAL
from eoreader.products import CleanMethod

# %%
# Open the product
folder = os.path.join("/home", "data", "DS3", "CI", "eoreader", "optical")
path = os.path.join(folder, "LC08_L1TP_200030_20201220_20210310_02_T1.tar")
reader = Reader()
prod = reader.open(path)

# %%
# %%timeit
prod.load(
    GREEN, 
    **{CLEAN_OPTICAL: CleanMethod.RAW}
)
prod.clean_tmp()
# Out:
# 2.43 s ± 81.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
prod.load(
    GREEN, 
    **{CLEAN_OPTICAL: CleanMethod.NODATA}
)
prod.clean_tmp()
# Out:
# 2.97 s ± 156 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
prod.load(
    GREEN, 
    **{CLEAN_OPTICAL: CleanMethod.CLEAN}
)
prod.clean_tmp()
# Out:
# 3.89 s ± 140 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Open the product
path = os.path.join(folder, "S2B_MSIL2A_20200114T065229_N0213_R020_T40REQ_20200114T094749.SAFE")
prod = reader.open(path)

# %%
# %%timeit
prod.load(
    GREEN,
    resolution=20.,
    **{CLEAN_OPTICAL: CleanMethod.RAW}
)
prod.clean_tmp()
# Out:
# 4.04 s ± 114 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
prod.load(
    GREEN,
    resolution=20.,
    **{CLEAN_OPTICAL: CleanMethod.NODATA}
)
prod.clean_tmp()
# Out:
# 4.54 s ± 150 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
prod.load(
    GREEN,
    resolution=20.,
    **{CLEAN_OPTICAL: CleanMethod.CLEAN}
)
prod.clean_tmp()
# Out:
# 4.93 s ± 131 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Open the product
path = os.path.join(folder, "S2B_MSIL2A_20210517T103619_N7990_R008_T30QVE_20211004T113819.SAFE")
prod = reader.open(path)

# %%
# %%timeit
prod.load(
    GREEN,
    resolution=20.,
    **{CLEAN_OPTICAL: CleanMethod.RAW}
)
prod.clean_tmp()
# Out:
# 3.64 s ± 90.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
prod.load(
    GREEN,
    resolution=20.,
    **{CLEAN_OPTICAL: CleanMethod.NODATA}
)
prod.clean_tmp()
# Out:
# 5.18 s ± 90.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
prod.load(
    GREEN,
    resolution=20.,
    **{CLEAN_OPTICAL: CleanMethod.CLEAN}
)
prod.clean_tmp()
# Out:
# 17.6 s ± 179 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
